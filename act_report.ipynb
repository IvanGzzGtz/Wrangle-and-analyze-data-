# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# The favorite_count_x columns explains how many likes the post has in twitter. We can get from this column using the nlargest() attribute that the post with most favorites has 132810 likes or favorites. If instead of nlargest() we use nsmallest() we get form this columns that the post with less favorites only has 52.
#
# The retweet_count_x columns explains how many retweets the post has in twitter. We can get from this column that the post with most favorites has 79515 likes or favorites, while the post with less retweets only has 0 retweets. We got this numbers using the nlargest and nsmallest attributes.
#
# If we plot a scatter plot with the x axis as favorite_count_x and then the y axis as retweet_count_x we get a good and positive correlation. The correlation tell us that the more favorites the post has, the more retweets it has.
#
# The bar plot shows us the most popular dog with this data. That is a Golden retriever breed. The second most popular dog is a Labrador breed. The third most popular dog is the Pembroke breed. The fourth most popular dog is the noisy Chihuahua breed. The fifth is the Pug breed. The other breeds didn't get to the top five breeds. Those five are the most popular dogs in these tweets.
#
# We have an approximately of 140 Golden retriever dogs, while the Chihuahuas breed only has an approximate of  80 dogs.
#
# ![image.png](attachment:image.png)
